# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import umap
import umap.plot
from rdkit import Chem
from joblib import Memory
import hdbscan
import networkx as nx
from minisom import MiniSom

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import davies_bouldin_score, silhouette_score, pairwise_distances, silhouette_samples
from sklearn.manifold import TSNE
from sklearn.neighbors import NearestNeighbors
from sklearn.utils import resample
from sklearn import datasets
from random import sample
from math import isnan
from numpy.random import uniform
from sklearn.cluster import KMeans, DBSCAN, Birch, OPTICS, AffinityPropagation
from sklearn.mixture import GaussianMixture

from sklearn.decomposition import PCA,NMF
from scipy.spatial.distance import cityblock, euclidean, pdist 

import holoviews as hv
hv.extension('bokeh')
import bokeh
from IPython.display import SVG
from rdkit.Chem.Draw import rdMolDraw2D
from bokeh.models import HoverTool
from bokeh.resources import INLINE
from yellowbrick.cluster import SilhouetteVisualizer
from bokeh.io import show
import importlib
import clustering_functions as cf


plt.rcParams['font.family'] = 'Avenir'  # Change font type
plt.rcParams['font.size'] = 16  # Change font size
# Out:
# /Users/therese/anaconda3/envs/high_dim_clust/lib/python3.9/site-packages/numba/np/ufunc/dufunc.py:343: NumbaWarning: Compilation requested for previously compiled argument types ((uint32,)). This has no effect and perhaps indicates a bug in the calling code (compiling a ufunc more than once for the same signature
#   warnings.warn(msg, errors.NumbaWarning)
# /Users/therese/anaconda3/envs/high_dim_clust/lib/python3.9/site-packages/numba/np/ufunc/dufunc.py:343: NumbaWarning: Compilation requested for previously compiled argument types ((uint32,)). This has no effect and perhaps indicates a bug in the calling code (compiling a ufunc more than once for the same signature
#   warnings.warn(msg, errors.NumbaWarning)
# ...

# %%
TO DOS:
# add in ability to make heatmaps by y response

# %% [markdown]
# # Read in Data

# %%
#more options for user
input_file = 'sample_input' #a file with smiles, descriptors and IDs 
sheet_name = 'Sheet1'
feature_start_column = 4 #column where descriptors start, 0-indexed
header_rows = 1 # adjust as needed 

id_column_name= 'Compound_Name' 
smiles_column_name= 'smiles' 
type_column_name = 'type' #if you don't need to plot any subsets enter: None (not 'None')

#_______________________________________________________________________________
#_______________________________________________________________________________
input_df = pd.read_excel(input_file+'.xlsx', sheet_name=sheet_name, header=header_rows)
input_df_shape = input_df.shape
allowed_empty = [smiles_column_name] 
input_df.dropna(subset=[col for col in input_df.columns if col not in allowed_empty], inplace=True) #drop columns with empty values, allow empty smiles
input_df_nona = input_df.shape
if input_df_shape[0] != input_df_nona[0]:
    print('Some rows with missing values were removed')
    print('Original number of datapoints: ', input_df_shape[0])
    print('New number of datapoints: ', input_df_nona[0])

feature_df = input_df.iloc[:,feature_start_column:] #just descriptors 
data = cf.get_mol_svg(input_df) #sets up for interactive plots

ID = data[id_column_name]
smiles = data[smiles_column_name]
image = data['mol_image']

if type_column_name is not None:
   type_column = data[type_column_name]
if type_column_name is None:
   type_column = None

# %%
# collinearity filter - add to cell above + have threshold as editing section 
threshold = 0.7
print(f'Shape of descriptors file before removing parameters with R^2 > {threshold} :',feature_df.shape)
df_corr = feature_df.corr()
df_not_correlated = ~(df_corr.mask(np.tril(np.ones([len(df_corr)]*2, dtype=bool))).abs() > threshold).any()
un_corr_idx = df_not_correlated.loc[df_not_correlated[df_not_correlated.index] == True].index
feature_df = feature_df[un_corr_idx]
print(f'Shape of descriptors file after removing parameters with R^2 > {threshold} : ',feature_df.shape)
# Out:
# Shape of descriptors file before removing parameters with R^2 > 0.7 : (450, 290)
# Shape of descriptors file after removing parameters with R^2 > 0.7 :  (450, 40)

# %%
#scale data
scaler = StandardScaler()
features_scaled = scaler.fit_transform(feature_df)

# %% [markdown]
# # Perform Dimensionality Reduction if Needed

# %% [markdown]
# ## UMAP

# %% [markdown]
# ### Optimize UMAP Hyperparameters

# %%
# take this with a grain of salt, a mathematically optimal UMAP is not necessarily the best UMAP for each case
# this is a good indicator of how well the UMAP is preserving the local structure of the data
# adjust functions to allow viewing of each UMAP hyperparameter combo so the user can choose 
# link to website explaining hyperparameters 

#let user define grid search parameters
def evaluate_clustering(features, umap_params, hdbscan_params):
    reducer = umap.UMAP(**umap_params)
    embedding = reducer.fit_transform(features)


    # Evaluate clustering with DB score
    if len(set(cluster_labels)) > 1:  # More than one cluster
        db_score = davies_bouldin_score(embedding, cluster_labels)
    else:
        db_score = np.inf
    
    return db_score, cluster_labels, embedding

def grid_search(features, umap_param_grid, hdbscan_param_grid):
    best_db_score = np.inf
    best_params = None
    best_labels = None
    best_embedding = None

    for umap_params in umap_param_grid:
        for hdbscan_params in hdbscan_param_grid:
            db_score, cluster_labels, embedding = evaluate_clustering(features, umap_params, hdbscan_params)
            
            # Optimization criteria
            if db_score < best_db_score:
                best_db_score = db_score
                best_params = (umap_params, hdbscan_params)
                best_labels = cluster_labels
                best_embedding = embedding

    return best_params, best_labels, best_embedding, best_db_score

umap_param_grid = [
    {'n_neighbors': n, 'min_dist': d, 'metric': 'euclidean'}
    for n in [5, 10, 15, 30, 50]
    for d in [0.0, 0.1, 0.3]
]

best_params, best_labels, best_embedding, best_db_score = grid_search(scaled_feats, umap_param_grid)

print(f'Best UMAP params: {best_params[0]}')
print(f'Best Davies-Bouldin score: {best_db_score}')

# Create a DataFrame with the UMAP results, original IDs, and cluster labels
umap_df = pd.DataFrame(best_embedding, columns=['UMAP1', 'UMAP2'])
umap_df['ID'] = ID
umap_df['Type'] = typecol
umap_df['Cluster'] = best_labels

# Plotting UMAP with HDBSCAN clusters, setting noise points to grey
plt.figure(figsize=(10, 8))

# Custom palette to include grey for noise
palette = sns.color_palette('viridis', as_cmap=True)
cluster_palette = {label: palette(i) for i, label in enumerate(set(best_labels) - {-1})}
cluster_palette[-1] = (0.5, 0.5, 0.5)  # Grey color for noise

sns.scatterplot(x='UMAP1', y='UMAP2', hue='Cluster', palette=cluster_palette, data=umap_df, legend='full')
plt.title(f'Optimized UMAP projection with HDBSCAN clusters')
plt.show()

# %% [markdown]
# ### Run and Plot UMAP

# %%
feature_set = features_scaled
export_to_excel = False #if you want to save as an excel file, set to True
save_plot_as_png = False #if you want to save as a png file, set to True
excel_file_name = 'umap_coordinates.xlsx'
plot_file_name = 'umap_plot.png'

#tune hyperparameters 
# for more info on UMAP + UMAP hyperparameters: pair-code.github.io/understanding-umap/
n_neighbors = 15 #umap default is 15, reasonable range 3-100
minimum_distance = 0.1 #umap default is 0.1, reasonable range 0.0-0.5
distance_metric = 'manhattan' 
random_state = 42 #for reproducibility (on a single machine)

#choose plot parameters - no subsets
alpha = 0.7 #transparency of points
color = '#7B1B79' 
marker = 'o' #point shape
size = 100 #point size
font_size = 14

#choose plot parameters - subsets (leave as None if not plotting subsets or if you want to use default plot settings)
alpha_value_mapping = None #dictionary {'type_1': 0.7, 'type_2': 0.5, ...}
color_mapping = None #dictionary {'type_1': '#7B1B79', 'type_2': '#FFA07A', ...}
marker_mapping = None #dictionary {'type_1': 'o', 'type_2': 's', ...}
size_mapping = None #dictionary {'type_1': 100, 'type_2': 200, ...}
plot_order = None # if you want to specify the order of plotting subsets for visualization purposes

#_______________________________________________________________________________
                        #shouldn't need to adjust below here
#_______________________________________________________________________________

umap_df = cf.plot_umap(features=feature_set, ID=ID, image=image, smiles=smiles, type_column=type_column, n_neighbors=n_neighbors,
                      min_dist=minimum_distance, distance_metric=distance_metric, random_state=random_state, alpha=alpha, color=color,
                      marker=marker, size=size, export_excel=export_to_excel, save_plot=save_plot_as_png, font_size=font_size,
                      alpha_value_mapping=alpha_value_mapping, color_mapping=color_mapping, marker_mapping=marker_mapping,
                      size_mapping=size_mapping, plot_order=plot_order,  excel_filename=excel_file_name, plot_filename=plot_file_name)
# Out:
# /Users/therese/.local/lib/python3.9/site-packages/umap_learn-0.5.5-py3.9.egg/umap/umap_.py:1944: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# ### Make Interactive UMAP Plot

# %%
## add option for heatmap of experimental data 
## this also should be plotted with types if needed

# %%
# #plot interactive HTML plot of UMAP space
int_plt = cf.scatter_plot(umap_df, x='UMAP1', y='UMAP2', svgs='image', hover_list=['name'], size=10, 
                       alpha=0.8 )
int_plt

# %% [markdown]
# ## TSNE

# %% [markdown]
# ### Run and Plot TSNE

# %%
feature_set = features_scaled
export_to_excel = False #if you want to save as an excel file, set to True
save_plot_as_png = False #if you want to save as a png file, set to True
excel_file_name = 'tsne_coordinates.xlsx'
plot_file_name = 'tsne_plot.png'

#tune hyperparameters 
# for more info on TSNE + TSNE hyperparameters https://distill.pub/2016/misread-tsne/
perplexity = 30 #tsne default is 30
early_exaggeration = 12 #tsne default is 12
learning_rate = 'auto' #range 10-1000
max_iterations = 1000 #tsne default is 1000
distance_metric = 'manhattan' 
random_state = 42 #for reproducibility 

#choose plot parameters - no subsets
alpha = 0.7 #transparency of points
color = '#7B1B79' 
marker = 'o' #point shape
size = 100 #point size
font_size = 14

#choose plot parameters - subsets (leave as None if not plotting subsets or if you want to use default plot settings)
alpha_value_mapping = None #dictionary {'type_1': 0.7, 'type_2': 0.5, ...}
color_mapping = None #dictionary {'type_1': '#7B1B79', 'type_2': '#FFA07A', ...}
marker_mapping = None #dictionary {'type_1': 'o', 'type_2': 's', ...}
size_mapping = None #dictionary {'type_1': 100, 'type_2': 200, ...}
plot_order = None # if you want to specify the order of plotting subsets for visualization purposes

#_______________________________________________________________________________
                        #shouldn't need to adjust below here
#_______________________________________________________________________________

tsne_df = cf.plot_tsne(features=feature_set, ID=ID, image=image, smiles=smiles, type_column=type_column, perplexity=perplexity, init='random',
                       early_exaggeration=early_exaggeration,learning_rate=learning_rate, distance_metric=distance_metric, random_state=random_state,
                       alpha=alpha, color=color,marker=marker, size=size, export_excel=export_to_excel, save_plot=save_plot_as_png, font_size=font_size,
                      alpha_value_mapping=alpha_value_mapping, color_mapping=color_mapping, marker_mapping=marker_mapping,
                      size_mapping=size_mapping, plot_order=plot_order,  excel_filename=excel_file_name, plot_filename=plot_file_name)

# %% [markdown]
# ## PCA

# %% [markdown]
# ### Run and Plot PCA

# %%
feature_set = features_scaled
export_to_excel = False #if you want to save as an excel file, set to True
save_plot_as_png = False #if you want to save as a png file, set to True
excel_file_name = 'pca_coordinates.xlsx'
plot_file_name = 'pca_plot.png'

n_components = 10 #number of components to keep
PCx = 'PC1' #which principal component to plot on x-axis
PCy = 'PC2' #which principal component to plot on y-axis
PCz = None #if you want a 3D plot, specify which principal component to plot on z-axis

#choose plot parameters - no subsets
alpha = 0.7 #transparency of points
color = '#7B1B79' 
marker = 'o' #point shape
size = 100 #point size
font_size = 14

#choose plot parameters - subsets (leave as None if not plotting subsets or if you want to use default plot settings)
alpha_value_mapping = None #dictionary {'type_1': 0.7, 'type_2': 0.5, ...}
color_mapping = None #dictionary {'type_1': '#7B1B79', 'type_2': '#FFA07A', ...}
marker_mapping = None #dictionary {'type_1': 'o', 'type_2': 's', ...}
size_mapping = None #dictionary {'type_1': 100, 'type_2': 200, ...}
plot_order = None # if you want to specify the order of plotting subsets for visualization purposes

#_______________________________________________________________________________
                        #shouldn't need to adjust below here
#_______________________________________________________________________________

pca_df =  cf.plot_pca(features=feature_set, ID=ID, image=image, smiles=smiles, type_column=type_column, n_components=n_components,
            alpha=alpha, color=color,marker=marker, size=size, export_excel=export_to_excel, save_plot=save_plot_as_png, font_size=font_size,
                      alpha_value_mapping=alpha_value_mapping, color_mapping=color_mapping, marker_mapping=marker_mapping,
                      size_mapping=size_mapping, plot_order=plot_order, pc_x = PCx, pc_y = PCy, pc_z = PCz, 
                      excel_filename=excel_file_name, plot_filename=plot_file_name)

# %% [markdown]
# ### Interactive PCA Plot

# %%
pc_x = 'PC1'
pc_y = 'PC2'

int_plt = cf.scatter_plot(pca_df, x='PC1', y='PC2', svgs='image', hover_list=['name'], size=10, 
                       alpha=0.8 )
int_plt

# %% [markdown]
# ## Plot Descriptor vs. Descriptor

# %% [markdown]
# ### Simple Descriptor v. Descriptor Plot

# %%
feature_set = pd.DataFrame(features_scaled, columns=feature_df.columns)
export_to_excel = False #if you want to save as an excel file, set to True
save_plot_as_png = False #if you want to save as a png file, set to True
excel_file_name = 'feature1_vs_feature2_coordinates.xlsx'
plot_file_name = 'feature1_vs_feature2_plot.png'

feature_x= 'HOMO_Boltz' 
feature_y = 'LUMO_Boltz'  
feature_z = None  # if you want to plot in 3D, set to 'feature#'

#choose plot parameters - no subsets
alpha = 0.7 #transparency of points
color = '#7B1B79' 
marker = 'o' #point shape
size = 100 #point size
font_size = 14

#choose plot parameters - subsets (leave as None if not plotting subsets or if you want to use default plot settings)
alpha_value_mapping = None #dictionary {'type_1': 0.7, 'type_2': 0.5, ...}
color_mapping = None #dictionary {'type_1': '#7B1B79', 'type_2': '#FFA07A', ...}
marker_mapping = None #dictionary {'type_1': 'o', 'type_2': 's', ...}
size_mapping = None #dictionary {'type_1': 100, 'type_2': 200, ...}
plot_order = None # if you want to specify the order of plotting subsets for visualization purposes

#_______________________________________________________________________________
                        #shouldn't need to adjust below here
#_______________________________________________________________________________

feature_x_y_df =  cf.plot_feature_v_feature(features=feature_set, ID=ID, image=image, smiles=smiles, type_column=type_column,
            alpha=alpha, color=color,marker=marker, size=size, export_excel=export_to_excel, save_plot=save_plot_as_png, font_size=font_size,
                      alpha_value_mapping=alpha_value_mapping, color_mapping=color_mapping, marker_mapping=marker_mapping,
                      size_mapping=size_mapping, plot_order=plot_order, feature_x = feature_x, feature_y = feature_y, feature_z = feature_z,
                      excel_filename=excel_file_name, plot_filename=plot_file_name)

# %% [markdown]
# ### Interactive Descriptor v. Descriptor Plot

# %%
feature_x = 'feature1'
feature_y = 'feature2'

int_plt = cf.scatter_plot(chem_space_df, x=feature_x, y=feature_y, svgs='image', hover_list=['name'], size=10, 
                       alpha=0.8 )
int_plt

# %% [markdown]
# # Clustering Techniques

# %% [markdown]
# ### Choose Number of Clusters

# %%
#options:
silhouette_scores, aic scores, bic scores, inertia 

# see silhouette scores for different numbers of clusters
# ideal plot: clusters have above average silhouette scores, size of the silhouette plots are similar 
# and thickness of the plot for each cluster is uniform
# higher score (up to 1) indicates better clustering

df = umap_df
X_coordinate_column = 'UMAP1'
Y_coordinate_column = 'UMAP2'

random_state = 42
min_clusters = 2
max_clusters = 10

silhouette_scoring = silhouette_scores(df, X_coordinate_column, Y_coordinate_column, min_clusters, max_clusters, kmeans_clustering, random_state)
aic_scoring = aic_bic_inertia_scores(df, X_coordinate_column, Y_coordinate_column, min_clusters, max_clusters, gmm_clustering, random_state)

# %%
####Clustering Functions Needed:
# k means - needs scoring (function added)
# ward - needs scoring 
# hdbscan - no scoring 
# dbscan - no scoring 
# gmm - needs scoring (function added)
# birch - needs scoring 
# spectral clustering

# %% [markdown]
# ## K-Means Clustering

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=2, min_samples=50, metric='manhattan')
umap_df['cluster'] = clusterer.fit_predict(X_umap)

def kmeans_clustering(data, random_state, n_clusters):
    model = KMeans(n_clusters=n_clusters, random_state=random_state)
    labels = model.fit_predict(data)
    return labels

plt.figure(figsize=(6, 6))
sns.scatterplot(x='UMAP1', y='UMAP2', hue='cluster', data=umap_df, palette='viridis', s=100)
plt.xlabel('UMAP Component 1')
plt.ylabel('UMAP Component 2')
plt.legend(title='Cluster')
plt.show()

# %%
gmm = GaussianMixture(n_components=3, random_state=2, covariance_type='full') 
gmm.fit(X_umap)
labels = gmm.predict(X_umap)

df['cluster'] = labels
plt.figure(figsize=(6, 6))
plt.scatter(df['UMAP1'], df['UMAP2'], c=df['cluster'], cmap='viridis', marker='o')
plt.xlabel('UMAP Component 1')
plt.ylabel('UMAP Component 2')
# plt.colorbar(label='Cluster')
plt.show()

# %%
df

# %%
# perform the clustering - not appropriate for use with UMAP!!!
kmeans = KMeans(n_clusters=7, random_state=10)  # Adjust n_clusters based on your data
clusters = kmeans.fit_predict(clustering_data)
df['cluster'] = clusters

#plot simply png
plt.figure(figsize=(8, 6))
sns.scatterplot(x='UMAP1', y='UMAP2', hue='cluster', palette='viridis', data=df[df['type'] == 'untested'],
                legend=False, markers='o', sizes=20, edgecolor=None, alpha=0.5)
sns.scatterplot(x='UMAP1', y='UMAP2',  color='black', data=df[df['type'] == 'tested'],
                legend=False, markers='*', sizes=50, edgecolor=None, alpha=1.0)
plt.title('KMeans Clustering of TSNE Reduced Space')
plt.show()

#plot interactive HTML plot
# int_plt = scatter_plot(df, x='TSNE1', y='TSNE2', svgs=image_column, hover_list=['name'], groupby='cluster', 
#                    color='Viridis', alpha=1.0, size=10)
int_plt = scatter_plot(df, x='UMAP1', y='UMAP2', svgs='image', hover_list=['name'], groupby='cluster', 
                   color='Viridis', alpha=0.8, size=10)
int_plt
# hv.extension('bokeh')
# hv.save(int_plt, 'kmeans_clust_prim_ami_results.html', backend='bokeh', resources=INLINE)

# %% [markdown]
# ## HDBSCAN Clustering

# %%
df

# %%
hv.extension('plotly')

clusterer = hdbscan.HDBSCAN(min_cluster_size=20, min_samples=50, metric='manhattan')
cluster_labels = clusterer.fit_predict(clustering_data)
clustered = (cluster_labels >= 0)

df['cluster'] = cluster_labels
# df.to_excel ('./undersampled_model/hdbscan_clusters_prim_amine.xlsx', index = False)

print("Fraction of points clustered:",np.sum(clustered) / data_scaled.data.shape[0])
plt.figure(figsize=(10, 8))
palette = sns.color_palette('viridis', as_cmap=True)
cluster_palette = {label: palette(i) for i, label in enumerate(set(cluster_labels) - {-1})}
cluster_palette[-1] = (0.5, 0.5, 0.5)  # Grey color for noise

sns.scatterplot(x='UMAP1', y='UMAP2', hue='cluster', palette='viridis', data=df)
# sns.scatterplot(x='TSNE1', y='TSNE2', hue='cluster', palette='viridis', data=df)
plt.show()

# %% [markdown]
# ## DBSCAN Clustering

# %%
dbscan = DBSCAN(metric='manhattan', min_samples=12)  # Adjust parameters based on your data
clusters = dbscan.fit_predict(clustering_data)
df['cluster'] = clusters

plt.figure(figsize=(10, 8))
sns.scatterplot(x='TSNE1', y='TSNE2', hue='cluster', palette='tab10', data=df, legend="full")
plt.show()

# %% [markdown]
# ## GMM Clustering

# %%
#perform the clustering with GMM + plot (not interactive)
X = df[['UMAP1', 'UMAP2']].values
n = 12

gmm = GaussianMixture(n_components=n, random_state=42, covariance_type='full') 
gmm.fit(X)
labels = gmm.predict(X)
print (labels)
soft_labels = gmm.predict_proba(X)
soft_labels_df = pd.DataFrame(soft_labels, columns=[f'prob_belonging_to_cluster_{i}' for i in range(n)])

df['cluster'] = labels
df = pd.concat([df, soft_labels_df], axis=1)
plt.figure(figsize=(10, 8))
plt.scatter(df['UMAP1'], df['UMAP2'], c=df['cluster'], cmap='viridis', marker='o')
plt.title('GMM Clustering on t-SNE Reduced Data')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.colorbar(label='Cluster')
plt.show()

# %%
df.to_excel ('./undersampled_model/prim_ami/gmm_clusters_prim_amine_16_non_colin_fts.xlsx', index = False)

# %%
# #perform the clustering with GMM + plot interactive plot
# X = df[['UMAP1', 'UMAP2']].values

# gmm = GaussianMixture(n_components=6, random_state=42, covariance_type='full') 
# gmm.fit(X)
# labels = gmm.predict(X)

# df['Cluster'] = labels
plt = scatter_plot(df, x='UMAP1', y='UMAP2', svgs=image_column, hover_list=['name'], groupby='Cluster', 
                   color='Viridis', alpha=1.0, size=10)
plt

#if you want to save the interactive plot as an HTML
hv.extension('bokeh')
hv.save(plt, 'interactive_plot.html', backend='bokeh', resources=INLINE)

# %%
# see how many components are reasonable 
n_components = np.arange(1, 15)
models = [GaussianMixture(n, covariance_type= 'full', random_state=0).fit(X)
          for n in n_components]

plt.plot(n_components, [m.bic(X) for m in models], label='BIC')
plt.plot(n_components, [m.aic(X) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('n_components');

# %% [markdown]
# ## BIRCH Algorithm Clustering

# %%
birch_model = Birch(threshold=0.8, n_clusters=5)
birch_model.fit(clustering_data)
labels = birch_model.predict(clustering_data)
df['Cluster'] = labels

plt.figure(figsize=(10, 6))
# sns.scatterplot(x='TSNE1', y='TSNE2', hue='Cluster', data=df, palette='viridis', s=40)
sns.scatterplot(x='UMAP1', y='UMAP2', hue='Cluster', data=df, palette='viridis', s=40)
plt.title('BIRCH Clustering on 2D t-SNE Reduced Data')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(title='Cluster')
plt.show()

# %%
n_clusters_range = range(2, 20) 
inertia_values = []
silhouette_scores = []

for n_clusters in n_clusters_range:
    birch_model = Birch(n_clusters=n_clusters, threshold=.5)
    birch_model.fit(clustering_data)
    labels = birch_model.predict(clustering_data)
    
    # Calculate the inertia (sum of squared distances to the closest centroid)
    # Note: BIRCH doesn't have an explicit inertia attribute, but we can calculate it manually
    cluster_centers = birch_model.subcluster_centers_
    inertia = np.sum([np.min(np.sum((point - cluster_centers)**2, axis=1)) for point in clustering_data])
    inertia_values.append(inertia)
    
    # Calculate the silhouette score
    silhouette_avg = silhouette_score(clustering_data, labels)
    silhouette_scores.append(silhouette_avg)
    

# Silhouette Score Plot
plt.subplot(1, 2, 2)
plt.plot(n_clusters_range, silhouette_scores, 'bo-')
plt.xlabel('Number of Clusters (n_clusters)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Optimal n_clusters')

plt.show()

# %% [markdown]
# ## OPTICS Clustering Algorithm

# %%
optics = OPTICS(min_samples=2, max_eps=.2)
optics_labels=optics.fit_predict(clustering_data)

plt.figure(figsize=(8, 6))
scatter = plt.scatter(clustering_data[:, 0], clustering_data[:, 1], c=optics_labels, s=50, alpha=0.6, cmap='viridis')
legend1 = plt.legend(*scatter.legend_elements(), title="Clusters")
plt.gca().add_artist(legend1)
plt.title('OPTICS Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()
